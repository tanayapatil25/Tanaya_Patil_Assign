# %% [markdown]
# Q1. Calculate z-score for the below data set, assuming sd = 1.5

# %% [markdown]
# ![WhatsApp%20Image%202023-12-27%20at%2012.36.03_7f848bdf.jpg](attachment:WhatsApp%20Image%202023-12-27%20at%2012.36.03_7f848bdf.jpg)

# %% [markdown]
# Q2 . What is one hot encoding?

# %% [raw]
# One hot encoding is a technique used to represent categorical variables in nominal data as numerical values in machine learning models 1. It is used when we have categorical data that needs to be converted into numerical data to fit into machine learning models.
#
# pd.get_dummies(data)

# %% [markdown]
# Q3. There are two types of transformer

# %% [markdown]
# ![WhatsApp%20Image%202023-12-27%20at%2012.43.54_b44eae1e.jpg](attachment:WhatsApp%20Image%202023-12-27%20at%2012.43.54_b44eae1e.jpg)

# %% [markdown]
# Q4. Assumptions of linear regression

# %% [raw]
# 1) Linearity
# 2) Multivariate normality
# 3) Homoscedasticity
# 4) Independence
# 5) No-multicollinearity

# %% [markdown]
# Q5. Gradient Descent Algorithm:

# %% [markdown]
# ![WhatsApp%20Image%202023-12-27%20at%2012.47.37_aab6fc0d.jpg](attachment:WhatsApp%20Image%202023-12-27%20at%2012.47.37_aab6fc0d.jpg)

# %% [markdown]
# Q6. Pandas Profilling

# %% [markdown]
# ![WhatsApp%20Image%202023-12-27%20at%2012.49.07_ead17d72.jpg](attachment:WhatsApp%20Image%202023-12-27%20at%2012.49.07_ead17d72.jpg)

# %% [markdown]
# Q7.

# %% [markdown]
# ![WhatsApp%20Image%202023-12-27%20at%2012.50.55_3c879601.jpg](attachment:WhatsApp%20Image%202023-12-27%20at%2012.50.55_3c879601.jpg)

# %% [markdown]
# Q8.

# %% [markdown]
# ![WhatsApp%20Image%202023-12-27%20at%2012.52.26_0d849e67.jpg](attachment:WhatsApp%20Image%202023-12-27%20at%2012.52.26_0d849e67.jpg)
